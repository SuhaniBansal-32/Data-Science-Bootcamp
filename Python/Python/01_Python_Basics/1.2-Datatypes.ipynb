# %%
## Integers Example
age = 35
print(type(age))
# Out:
# <class 'int'>

# %%
## Floating point datatype
height = 5.11
type(height)
# Out:
# float

# %%
## string datatype example
name = "Suhani"
type(name)
# Out:
# str

# %%
## boolean datatype
is_student = True
print(type(is_student))
# Out:
# <class 'bool'>

# %%
bool() # False
a = 10
b = 10
a == b
# Out:
# True

# %%
## Common errors
# result = "hello" + 5
result = "hello" + str(5) ## typecasting
## type conversion
height = 5.11
int(height) ## from float to int

# %%
## Real-world examples using lists in python

# Example 1: Manage a To Do List
# Out:
# 2

# %%
# Create a To Do List To Keep Track Of Tasks
to_do_list = ["Buy Groceries","Clean the house","Pay bills"]

## Adding task to To Do
def add_task(task):
    to_do_list.append(task)
    return("task added successfully!")

add_task("Scehdule meeting")
add_task("Go for a run")
print(to_do_list)

## Removing a completed task
def remove_task(task):

    to_do_list.remove(task)
    return("task completed successfully!")

remove_task("Clean the house")
print(to_do_list)

## checking if a task in the list
def check_task(task):
    if task in to_do_list:
        return f"{task} already exists."
    else:
        return f"{task} doesn't exist"

print(check_task("Go for a run"))

if "Pay bills" in to_do_list:
    print("Don't forget to pay the utility bills!")

print("Remaining Tasks: ", len(to_do_list))
print("To Do List remaining: ")
for idx,task in enumerate(to_do_list):
    print(f"{idx+1}. {task}")
# Out:
# ['Buy Groceries', 'Clean the house', 'Pay bills', 'Scehdule meeting', 'Go for a run']
# ['Buy Groceries', 'Pay bills', 'Scehdule meeting', 'Go for a run']
# Go for a run already exists.
# Don't forget to pay the utility bills!
# Remaining Tasks:  4
# To Do List remaining:
# 1. Buy Groceries
# 2. Pay bills
# 3. Scehdule meeting
# 4. Go for a run

# %%
## Example - 2: Organizing Student Grades
# Create a list to store and calculate grades for students

# Organizing student grades
grades = [85, 92, 78, 90, 88]
# adding a new grade
grades.append(95)

# Calculating the average grades
average_grade = sum(grades)/len(grades)
print(f"Average Grade: {average_grade}")

# Finding the highest and lowest grade
highest_grade = max(grades)
lowest_grade = min(grades)
print(f"Highest Grade: {highest_grade}")
print(f"Lowest Grade: {lowest_grade}")
# Out:
# Average Grade: 88.0
# Highest Grade: 95
# Lowest Grade: 78

# %%
## Example - 3: Managing an Inventory
# Use a list to manage inventory items in a store

# Managing an inventory
inventory = ["apples","bananas","oranges","grapes"]

# Adding a new item
inventory.append("strawberries")

# Removing an item that is out of stock
inventory.remove("bananas")

# Checking if an item is in stock
item = "oranges"
if item in inventory:
    print(f"{item} are in stock.")
else:
    print(f"{item} are out of stock.")

# Printing the inventory
print("Inventory List:")
for item in inventory:
    print(f"- {item}")
# Out:
# oranges are in stock.
# Inventory List:
# - apples
# - oranges
# - grapes
# - strawberries

# %%
## Example - 4: Collecting User Feedback
# Use a list to collect and analyze user feedback

# Collecting user feedback
feedback = ["Great service!","Very satisfied","Could be better","Excellent experience"]

# Adding new feedback
feedback.append("Not happy with the service")

# Counting specific feedback
positive_feedback_count = sum(1 for comment in feedback if "great" in comment.lower() or "excellent" in comment.lower())
print(f"Positive Feedback Count: {positive_feedback_count}")

# Printing all feedback
print("User Feedback: ")
for comment in feedback:
    print(f"- {comment}")
# Out:
# Positive Feedback Count: 2
# User Feedback:
# - Great service!
# - Very satisfied
# - Could be better
# - Excellent experience
# - Not happy with the service

# %%
keys = ['name','age','country','gender']
values = ['Suhani',21,'India']
def merge_lists_to_dictionary(keys, values):
    # Your code goes here

    my_dict = {}
    if(keys and values):
        for key,value in zip(keys,values):
            my_dict[key] = value
        
        for key in keys:
            if key not in my_dict:
                my_dict[key] = 'Not Defined'
        return my_dict
    else:
        return {}


merge_lists_to_dictionary(keys,values)
# Out:
# {'name': 'Suhani', 'age': 21, 'country': 'India', 'gender': 'Not Defined'}

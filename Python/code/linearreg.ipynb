# %%
print(1+2)
# Out:
# 3

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.3 MB 2.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/11.3 MB 2.3 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.3 MB 2.5 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/11.3 MB 2.8 MB/s eta 0:00:04
#    ------------ --------------------------- 3.4/11.3 MB 2.9 MB/s eta 0:00:03
#    -------------- ------------------------- 4.2/11.3 MB 3.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.7/11.3 MB 3.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.0/11.3 MB 3.0 MB/s eta 0:00:03
#    ------------------- -------------------- 5.5/11.3 MB 2.8 MB/s eta 0:00:03
#    --------------------- ------------------ 6.0/11.3 MB 2.8 MB/s eta 0:00:02
# ...
